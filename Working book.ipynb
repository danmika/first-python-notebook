# %%
import pandas

# %%
import pandas as pd

# %%
pd.read.csv("http://www.firstpythonnotebook.org/_static/committees.csv")
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-3-7132d784e446> in <module>()
# ----> 1 pd.read.csv("http://www.firstpythonnotebook.org/_static/committees.csv")
#
# AttributeError: 'module' object has no attribute 'read'

# %%
pd.read_csv("http://www.firstpythonnotebook.org/_static/committees.csv")
# Out:
#                                           ocd_prop_id  calaccess_prop_id  \
# 0    ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 1    ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 2    ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 3    ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 4    ocd-contest/85990193-9d6f-4600-b8e7-bf1317841d82            1362198
# 5    ocd-contest/85990193-9d6f-4600-b8e7-bf1317841d82            1362198
# 6    ocd-contest/85990193-9d6f-4600-b8e7-bf1317841d82            1362198
# 7    ocd-contest/9fb6a199-7520-433c-a290-83e016a9d389            1376142
# 8    ocd-contest/9fb6a199-7520-433c-a290-83e016a9d389            1376142
# 9    ocd-contest/9fb6a199-7520-433c-a290-83e016a9d389            1376142
# 10   ocd-contest/9fb6a199-7520-433c-a290-83e016a9d389            1376142
# 11   ocd-contest/e0c5f9f0-63a9-4c15-9a5c-017e20ac15bc            1381642
# ...

# %%
props = pd.read_csv("http://www.firstpythonnotebook.org/_static/committees.csv")

# %%
print props
# Out:
#                                           ocd_prop_id  calaccess_prop_id  \
# 0    ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 1    ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 2    ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 3    ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 4    ocd-contest/85990193-9d6f-4600-b8e7-bf1317841d82            1362198
# 5    ocd-contest/85990193-9d6f-4600-b8e7-bf1317841d82            1362198
# 6    ocd-contest/85990193-9d6f-4600-b8e7-bf1317841d82            1362198
# 7    ocd-contest/9fb6a199-7520-433c-a290-83e016a9d389            1376142
# 8    ocd-contest/9fb6a199-7520-433c-a290-83e016a9d389            1376142
# 9    ocd-contest/9fb6a199-7520-433c-a290-83e016a9d389            1376142
# 10   ocd-contest/9fb6a199-7520-433c-a290-83e016a9d389            1376142
# 11   ocd-contest/e0c5f9f0-63a9-4c15-9a5c-017e20ac15bc            1381642
# ...

# %%
props
# Out:
#                                           ocd_prop_id  calaccess_prop_id  \
# 0    ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 1    ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 2    ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 3    ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 4    ocd-contest/85990193-9d6f-4600-b8e7-bf1317841d82            1362198
# 5    ocd-contest/85990193-9d6f-4600-b8e7-bf1317841d82            1362198
# 6    ocd-contest/85990193-9d6f-4600-b8e7-bf1317841d82            1362198
# 7    ocd-contest/9fb6a199-7520-433c-a290-83e016a9d389            1376142
# 8    ocd-contest/9fb6a199-7520-433c-a290-83e016a9d389            1376142
# 9    ocd-contest/9fb6a199-7520-433c-a290-83e016a9d389            1376142
# 10   ocd-contest/9fb6a199-7520-433c-a290-83e016a9d389            1376142
# 11   ocd-contest/e0c5f9f0-63a9-4c15-9a5c-017e20ac15bc            1381642
# ...

# %%
props.head()
# Out:
#                                         ocd_prop_id  calaccess_prop_id  \
# 0  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 1  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 2  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 3  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 4  ocd-contest/85990193-9d6f-4600-b8e7-bf1317841d82            1362198
#
#    ccdc_prop_id                                          prop_name  \
# 0            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 1            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 2            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 3            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 4            71  PROPOSITION 052 - STATE FEES ON HOSPITALS. FED...
#
#    ccdc_committee_id  calaccess_committee_id  \
# 0                382                 1374469
# ...

# %%
props.head()
# Out:
#                                         ocd_prop_id  calaccess_prop_id  \
# 0  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 1  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 2  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 3  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 4  ocd-contest/85990193-9d6f-4600-b8e7-bf1317841d82            1362198
#
#    ccdc_prop_id                                          prop_name  \
# 0            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 1            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 2            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 3            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 4            71  PROPOSITION 052 - STATE FEES ON HOSPITALS. FED...
#
#    ccdc_committee_id  calaccess_committee_id  \
# 0                382                 1374469
# ...

# %%
props.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 8 columns):
# ocd_prop_id               102 non-null object
# calaccess_prop_id         102 non-null int64
# ccdc_prop_id              102 non-null int64
# prop_name                 102 non-null object
# ccdc_committee_id         102 non-null int64
# calaccess_committee_id    102 non-null int64
# committee_name            102 non-null object
# committee_position        102 non-null object
# dtypes: int64(4), object(4)
# memory usage: 6.4+ KB

# %%
props.head
# Out:
# <bound method DataFrame.head of                                           ocd_prop_id  calaccess_prop_id  \
# 0    ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 1    ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 2    ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 3    ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 4    ocd-contest/85990193-9d6f-4600-b8e7-bf1317841d82            1362198
# 5    ocd-contest/85990193-9d6f-4600-b8e7-bf1317841d82            1362198
# 6    ocd-contest/85990193-9d6f-4600-b8e7-bf1317841d82            1362198
# 7    ocd-contest/9fb6a199-7520-433c-a290-83e016a9d389            1376142
# 8    ocd-contest/9fb6a199-7520-433c-a290-83e016a9d389            1376142
# 9    ocd-contest/9fb6a199-7520-433c-a290-83e016a9d389            1376142
# 10   ocd-contest/9fb6a199-7520-433c-a290-83e016a9d389            1376142
# ...

# %%
props.head()
# Out:
#                                         ocd_prop_id  calaccess_prop_id  \
# 0  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 1  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 2  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 3  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 4  ocd-contest/85990193-9d6f-4600-b8e7-bf1317841d82            1362198
#
#    ccdc_prop_id                                          prop_name  \
# 0            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 1            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 2            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 3            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 4            71  PROPOSITION 052 - STATE FEES ON HOSPITALS. FED...
#
#    ccdc_committee_id  calaccess_committee_id  \
# 0                382                 1374469
# ...

# %%
props.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 8 columns):
# ocd_prop_id               102 non-null object
# calaccess_prop_id         102 non-null int64
# ccdc_prop_id              102 non-null int64
# prop_name                 102 non-null object
# ccdc_committee_id         102 non-null int64
# calaccess_committee_id    102 non-null int64
# committee_name            102 non-null object
# committee_position        102 non-null object
# dtypes: int64(4), object(4)
# memory usage: 6.4+ KB

# %%
contribs = pd.read_csv("http://www.firstpythonnotebook.org/_static/contributions.csv")

# %%
pd.read_csv(C:\Code\contributions.csv)
# Out:
#   File "<ipython-input-15-d7bc8192b881>", line 1
#     pd.read_csv(C:\Code\contributions.csv)
#                  ^
# SyntaxError: invalid syntax

# %%
pd.read_csv("C:\Code\contributions.csv")
# Out:
#        calaccess_committee_id  \
# 0                     1386560
# 1                     1386560
# 2                     1386560
# 3                     1386560
# 4                     1386560
# 5                     1386560
# 6                     1386560
# 7                     1386560
# 8                     1386560
# 9                     1386560
# 10                    1386560
# 11                    1386560
# 12                    1386560
# 13                    1386560
# 14                    1386560
# 15                    1386560
# 16                    1386560
# 17                    1386560
# 18                    1386560
# 19                    1386560
# 20                    1386560
# 21                    1386560
# 22                    1386560
# 23                    1386560
# 24                    1386560
# 25                    1386560
# 26                    1372902
# 27                    1372902
# 28                    1372902
# 29                    1372902
# ...

# %%
contribs.head()
# Out:
#    calaccess_committee_id                              committee_name  \
# 0                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 1                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 2                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 3                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 4                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
#
#    calaccess_filing_id date_received contributor_lastname  \
# 0              2083796    2016-09-18              BERGMAN
# 1              2083796    2016-09-18                KAHLE
# 2              2083796    2016-07-15             MCDEVITT
# 3              2083796    2016-08-10      WARREN-SAMARIPA
# 4              2083796    2016-07-26      WARREN-SAMARIPA
#
#   contributor_firstname contributor_city contributor_state contributor_zip  \
# 0              GRETCHEN    SPRING VALLEY                CA           91978
# ...

# %%
contribs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56379 entries, 0 to 56378
# Data columns (total 13 columns):
# calaccess_committee_id          56379 non-null int64
# committee_name                  56379 non-null object
# calaccess_filing_id             56379 non-null int64
# date_received                   56379 non-null object
# contributor_lastname            56375 non-null object
# contributor_firstname           53411 non-null object
# contributor_city                56369 non-null object
# contributor_state               56363 non-null object
# contributor_zip                 56366 non-null object
# contributor_employer            48572 non-null object
# contributor_occupation          53273 non-null object
# contributor_is_self_employed    56379 non-null bool
# amount                          56379 non-null float64
# dtypes: bool(1), float64(1), int64(2), object(9)
# memory usage: 5.2+ MB

# %%
props.prop_name
# Out:
# 0      PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 1      PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 2      PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 3      PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 4      PROPOSITION 052 - STATE FEES ON HOSPITALS. FED...
# 5      PROPOSITION 052 - STATE FEES ON HOSPITALS. FED...
# 6      PROPOSITION 052 - STATE FEES ON HOSPITALS. FED...
# 7      PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOT...
# 8      PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOT...
# 9      PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOT...
# 10     PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOT...
# 11     PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...
# 12     PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...
# 13     PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...
# 14     PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...
# 15     PROPOSITION 055 - TAX EXTENSION TO FUND EDUCAT...
# ...

# %%
props.prop_name.value_counts()
# Out:
# PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE CRIMINAL PROCEEDINGS AND SENTENCING. INITIATIVE CONSTITUTIONAL AMENDMENT AND STATUTE.                           13
# PROPOSITION 056 - CIGARETTE TAX TO FUND HEALTHCARE, TOBACCO USE PREVENTION, RESEARCH, AND LAW ENFORCEMENT. INITIATIVE CONSTITUTIONAL AMENDMENT AND STATUTE.    12
# PROPOSITION 064- MARIJUANA LEGALIZATION. INITIATIVE STATUTE.                                                                                                   11
# PROPOSITION 066- DEATH PENALTY. PROCEDURES. INITIATIVE STATUTE.                                                                                                 9
# PROPOSITION 055 - TAX EXTENSION TO FUND EDUCATION AND HEALTHCARE. INITIATIVE CONSTITUTIONAL AMENDMENT.                                                          8
# PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON SINGLE-USE PLASTIC BAGS.                                                                                         7
# ...

# %%
props.prop_name.value_counts().reset_index()
# Out:
#                                                 index  prop_name
# 0   PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE...         13
# 1   PROPOSITION 056 - CIGARETTE TAX TO FUND HEALTH...         12
# 2   PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...         11
# 3   PROPOSITION 066- DEATH PENALTY. PROCEDURES. IN...          9
# 4   PROPOSITION 055 - TAX EXTENSION TO FUND EDUCAT...          8
# 5   PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON...          7
# 6   PROPOSITION 062- DEATH PENALTY. INITIATIVE STA...          7
# 7   PROPOSITION 059- SB 254 (CHAPTER 20, STATUTES ...          6
# 8   PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOT...          4
# 9   PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...          4
# 10  PROPOSITION 058 - SB 1174 (CHAPTER 753, STATUT...          4
# 11  PROPOSITION 063- FIREARMS. AMMUNITION SALES. I...          4
# 12  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...          4
# ...

# %%
props.prop_name.value_counts()
# Out:
# PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE CRIMINAL PROCEEDINGS AND SENTENCING. INITIATIVE CONSTITUTIONAL AMENDMENT AND STATUTE.                           13
# PROPOSITION 056 - CIGARETTE TAX TO FUND HEALTHCARE, TOBACCO USE PREVENTION, RESEARCH, AND LAW ENFORCEMENT. INITIATIVE CONSTITUTIONAL AMENDMENT AND STATUTE.    12
# PROPOSITION 064- MARIJUANA LEGALIZATION. INITIATIVE STATUTE.                                                                                                   11
# PROPOSITION 066- DEATH PENALTY. PROCEDURES. INITIATIVE STATUTE.                                                                                                 9
# PROPOSITION 055 - TAX EXTENSION TO FUND EDUCATION AND HEALTHCARE. INITIATIVE CONSTITUTIONAL AMENDMENT.                                                          8
# PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON SINGLE-USE PLASTIC BAGS.                                                                                         7
# ...

# %%
props.prop_name == 'PROPOSITION 064- MARIJUANA LEGALIZATION. INITIATIVE STATUTE.'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 72     False
# 73     False
# 74      True
# 75      True
# 76      True
# 77      True
# 78      True
# 79      True
# 80      True
# 81      True
# 82      True
# 83      True
# 84      True
# 85     False
# 86     False
# 87     False
# 88     False
# 89     False
# 90     False
# 91     False
# 92     False
# 93     False
# 94     False
# 95     False
# 96     False
# 97     False
# 98     False
# 99     False
# 100    False
# 101    False
# Name: prop_name, Length: 102, dtype: bool

# %%
import pandas as pd

# %%
props.props_name
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-6-47f0e93674f3> in <module>()
# ----> 1 props.props_name
#
# NameError: name 'props' is not defined

# %%
props = pd.read_csv("http://www.firstpythonnotebook.org/_static/committees.csv")

# %%
props.name
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-8-d13f1f7abb8f> in <module>()
# ----> 1 props.name
#
# c:\code\first-python-notebook\lib\site-packages\pandas\core\generic.pyc in __getattr__(self, name)
#    3079             if name in self._info_axis:
#    3080                 return self[name]
# -> 3081             return object.__getattribute__(self, name)
#    3082
#    3083     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'name'

# %%
props.prop_name
# Out:
# 0      PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 1      PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 2      PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 3      PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 4      PROPOSITION 052 - STATE FEES ON HOSPITALS. FED...
# 5      PROPOSITION 052 - STATE FEES ON HOSPITALS. FED...
# 6      PROPOSITION 052 - STATE FEES ON HOSPITALS. FED...
# 7      PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOT...
# 8      PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOT...
# 9      PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOT...
# 10     PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOT...
# 11     PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...
# 12     PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...
# 13     PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...
# 14     PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...
# 15     PROPOSITION 055 - TAX EXTENSION TO FUND EDUCAT...
# ...

# %%
props.prop_name.value_counts()
# Out:
# PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE CRIMINAL PROCEEDINGS AND SENTENCING. INITIATIVE CONSTITUTIONAL AMENDMENT AND STATUTE.                           13
# PROPOSITION 056 - CIGARETTE TAX TO FUND HEALTHCARE, TOBACCO USE PREVENTION, RESEARCH, AND LAW ENFORCEMENT. INITIATIVE CONSTITUTIONAL AMENDMENT AND STATUTE.    12
# PROPOSITION 064- MARIJUANA LEGALIZATION. INITIATIVE STATUTE.                                                                                                   11
# PROPOSITION 066- DEATH PENALTY. PROCEDURES. INITIATIVE STATUTE.                                                                                                 9
# PROPOSITION 055 - TAX EXTENSION TO FUND EDUCATION AND HEALTHCARE. INITIATIVE CONSTITUTIONAL AMENDMENT.                                                          8
# PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON SINGLE-USE PLASTIC BAGS.                                                                                         7
# ...

# %%
props.prop_name == 'PROPOSITION 064- MARIJUANA LEGALIZATION. INITIATIVE STATUTE.'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 72     False
# 73     False
# 74      True
# 75      True
# 76      True
# 77      True
# 78      True
# 79      True
# 80      True
# 81      True
# 82      True
# 83      True
# 84      True
# 85     False
# 86     False
# 87     False
# 88     False
# 89     False
# 90     False
# 91     False
# 92     False
# 93     False
# 94     False
# 95     False
# 96     False
# 97     False
# 98     False
# 99     False
# 100    False
# 101    False
# Name: prop_name, Length: 102, dtype: bool

# %%
props[props.prop_name == 'PROPOSITION 064- MARIJUANA LEGALIZATION. INITIATIVE STATUTE.']
# Out:
#                                          ocd_prop_id  calaccess_prop_id  \
# 74  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 75  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 76  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 77  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 78  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 79  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 80  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 81  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 82  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 83  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 84  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
#
#     ccdc_prop_id                                          prop_name  \
# ...

# %%
prop = props[props.prop_name == 'PROPOSITION 064- MARIJUANA LEGALIZATION. INITIATIVE STATUTE.']

# %%
prop.head()
# Out:
#                                          ocd_prop_id  calaccess_prop_id  \
# 74  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 75  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 76  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 77  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 78  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
#
#     ccdc_prop_id                                          prop_name  \
# 74            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 75            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 76            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 77            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 78            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
#
#     ccdc_committee_id  calaccess_committee_id  \
# 74                456                 1381808
# ...

# %%
prop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11 entries, 74 to 84
# Data columns (total 8 columns):
# ocd_prop_id               11 non-null object
# calaccess_prop_id         11 non-null int64
# ccdc_prop_id              11 non-null int64
# prop_name                 11 non-null object
# ccdc_committee_id         11 non-null int64
# calaccess_committee_id    11 non-null int64
# committee_name            11 non-null object
# committee_position        11 non-null object
# dtypes: int64(4), object(4)
# memory usage: 792.0+ bytes

# %%
contribs.info()
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-16-7e6f8a0b998e> in <module>()
# ----> 1 contribs.info()
#
# NameError: name 'contribs' is not defined

# %%
contribs = pd.read_csv("C:\Code\contributions.csv")

# %%
contribs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56379 entries, 0 to 56378
# Data columns (total 13 columns):
# calaccess_committee_id          56379 non-null int64
# committee_name                  56379 non-null object
# calaccess_filing_id             56379 non-null int64
# date_received                   56379 non-null object
# contributor_lastname            56375 non-null object
# contributor_firstname           53411 non-null object
# contributor_city                56369 non-null object
# contributor_state               56363 non-null object
# contributor_zip                 56366 non-null object
# contributor_employer            48572 non-null object
# contributor_occupation          53273 non-null object
# contributor_is_self_employed    56379 non-null bool
# amount                          56379 non-null float64
# dtypes: bool(1), float64(1), int64(2), object(9)
# memory usage: 5.2+ MB

# %%
props.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 8 columns):
# ocd_prop_id               102 non-null object
# calaccess_prop_id         102 non-null int64
# ccdc_prop_id              102 non-null int64
# prop_name                 102 non-null object
# ccdc_committee_id         102 non-null int64
# calaccess_committee_id    102 non-null int64
# committee_name            102 non-null object
# committee_position        102 non-null object
# dtypes: int64(4), object(4)
# memory usage: 6.4+ KB

# %%
merged = pd.merge(prop, contribs, on=)
# Out:
#   File "<ipython-input-20-0e2d5fde41ac>", line 1
#     merged = pd.merge(prop, contribs, on=)
#                                          ^
# SyntaxError: invalid syntax

# %%
merged = pd.merge(prop, contribs, on="calaccess.committee.id")
# Out:
# KeyErrorTraceback (most recent call last)
# <ipython-input-21-76e1fd62d3a8> in <module>()
# ----> 1 merged = pd.merge(prop, contribs, on="calaccess.committee.id")
#
# c:\code\first-python-notebook\lib\site-packages\pandas\core\reshape\merge.pyc in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator)
#      51                          right_on=right_on, left_index=left_index,
#      52                          right_index=right_index, sort=sort, suffixes=suffixes,
# ---> 53                          copy=copy, indicator=indicator)
#      54     return op.get_result()
#      55
#
# c:\code\first-python-notebook\lib\site-packages\pandas\core\reshape\merge.pyc in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator)
#     556         (self.left_join_keys,
#     557          self.right_join_keys,
# --> 558          self.join_names) = self._get_merge_keys()
#     559
# ...

# %%
merged = pd.merge(prop, contribs, on="calaccess_committee_id")

# %%
merged.head()
# Out:
#                                         ocd_prop_id  calaccess_prop_id  \
# 0  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 1  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 2  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 3  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 4  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
#
#    ccdc_prop_id                                          prop_name  \
# 0            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 1            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 2            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 3            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 4            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
#
#    ccdc_committee_id  calaccess_committee_id  \
# 0                456                 1381808
# ...

# %%
merged.info
# Out:
# <bound method DataFrame.info of                                           ocd_prop_id  calaccess_prop_id  \
# 0    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 1    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 2    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 3    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 4    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 5    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 6    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 7    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 8    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 9    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 10   ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# ...

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 860 entries, 0 to 859
# Data columns (total 20 columns):
# ocd_prop_id                     860 non-null object
# calaccess_prop_id               860 non-null int64
# ccdc_prop_id                    860 non-null int64
# prop_name                       860 non-null object
# ccdc_committee_id               860 non-null int64
# calaccess_committee_id          860 non-null int64
# committee_name_x                860 non-null object
# committee_position              860 non-null object
# committee_name_y                860 non-null object
# calaccess_filing_id             860 non-null int64
# date_received                   860 non-null object
# contributor_lastname            860 non-null object
# contributor_firstname           750 non-null object
# contributor_city                860 non-null object
# contributor_state               860 non-null object
# contributor_zip                 860 non-null object
# ...

# %%
merged.amount.sum()
# Out:
# 35177017.640000001

# %%
merged.committee_position.value_counts()
# Out:
# SUPPORT    762
# OPPOSE      98
# Name: committee_position, dtype: int64

# %%
support = merged[merged.committee_position == 'SUPPORT']

# %%
oppose = merged[merged.committee_position == 'OPPOSE']

# %%
oppose.ammount.sum()
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-30-791244603c9b> in <module>()
# ----> 1 oppose.ammount.sum()
#
# c:\code\first-python-notebook\lib\site-packages\pandas\core\generic.pyc in __getattr__(self, name)
#    3079             if name in self._info_axis:
#    3080                 return self[name]
# -> 3081             return object.__getattribute__(self, name)
#    3082
#    3083     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'ammount'

# %%
oppose.amount.sum()
# Out:
# 2501211.6400000001

# %%
support.amount.sum()
# Out:
# 32675806.0

# %%
support.amount.sum() / merged.amount.sum()
# Out:
# 0.92889642704798669

# %%
merged.sort_values("amount")
# Out:
#                                           ocd_prop_id  calaccess_prop_id  \
# 260  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 793  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 806  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 727  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 698  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 227  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 812  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 127  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 118  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 220  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 101  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 28   ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# ...

# %%
merged.sort_values("amount", ascending=False)
# Out:
#                                           ocd_prop_id  calaccess_prop_id  \
# 142  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 79   ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 846  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 851  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 852  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 141  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 78   ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 143  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 253  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 259  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 850  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 839  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# ...

# %%
oppose.sort_values()
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-36-2f7a338b3f09> in <module>()
# ----> 1 oppose.sort_values()
#
# TypeError: sort_values() takes at least 2 arguments (1 given)

# %%
oppose.sort_values("amount", ascending=False).head()
# Out:
#                                           ocd_prop_id  calaccess_prop_id  \
# 839  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 312  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 310  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 308  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 840  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
#
#      ccdc_prop_id                                          prop_name  \
# 839            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 312            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 310            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 308            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 840            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
#
#      ccdc_committee_id  calaccess_committee_id  \
# 839                463                 1387789
# ...

# %%
merged.groupby("committee_name_x").amount.sum()
# Out:
# committee_name_x
# ADULT USE CAMPAIGN FOR PROPOSITION 64; THE                                                                                                                                                              17089.00
# CALIFORNIANS FOR RESPONSIBLE MARIJUANA REFORM, SPONSORED BY DRUG POLICY ACTION, YES ON PROP. 64                                                                                                        860470.00
# CALIFORNIANS FOR SENSIBLE REFORM, SPONSORED BY GHOST MANAGEMENT GROUP, LLC DBA WEEDMAPS                                                                                                                850000.00
# DRUG POLICY ACTION - NON PROFIT 501C4, YES ON PROP. 64                                                                                                                                                4470000.00
# ...

# %%
merged.groupby("committee_name_x").amount.sum().reset_index()
# Out:
#                                      committee_name_x       amount
# 0          ADULT USE CAMPAIGN FOR PROPOSITION 64; THE     17089.00
# 1   CALIFORNIANS FOR RESPONSIBLE MARIJUANA REFORM,...    860470.00
# 2   CALIFORNIANS FOR SENSIBLE REFORM, SPONSORED BY...    850000.00
# 3   DRUG POLICY ACTION - NON PROFIT 501C4, YES ON ...   4470000.00
# 4        FUND FOR POLICY REFORM (NONPROFIT 501(C)(4))   6140000.00
# 5   MARIJUANA POLICY PROJECT OF CALIFORNIA, YES ON 64    739200.00
# 6                         MOMS STRONG AGAINST PROP 64      6281.64
# 7                              NEW APPROACH PAC (MPO)   3865000.00
# 8   PUBLIC AND MENTAL HEALTH ADVOCATES AGAINST 64,...   1130930.00
# 9   SAM ACTION, INC., A COMMITTEE AGAINST PROPOSIT...   1364000.00
# 10  YES ON 64, CALIFORNIANS TO CONTROL, REGULATE A...  15734047.00

# %%
merged.groupby("committee_name_x").amount.sum().reset_index().sort_values("amount", ascending)
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-40-7bd2094a10c5> in <module>()
# ----> 1 merged.groupby("committee_name_x").amount.sum().reset_index().sort_values("amount", ascending)
#
# NameError: name 'ascending' is not defined

# %%
merged.groupby("committee_name_x").amount.sum().reset_index().sort_values("amount", ascending=False)
# Out:
#                                      committee_name_x       amount
# 10  YES ON 64, CALIFORNIANS TO CONTROL, REGULATE A...  15734047.00
# 4        FUND FOR POLICY REFORM (NONPROFIT 501(C)(4))   6140000.00
# 3   DRUG POLICY ACTION - NON PROFIT 501C4, YES ON ...   4470000.00
# 7                              NEW APPROACH PAC (MPO)   3865000.00
# 9   SAM ACTION, INC., A COMMITTEE AGAINST PROPOSIT...   1364000.00
# 8   PUBLIC AND MENTAL HEALTH ADVOCATES AGAINST 64,...   1130930.00
# 1   CALIFORNIANS FOR RESPONSIBLE MARIJUANA REFORM,...    860470.00
# 2   CALIFORNIANS FOR SENSIBLE REFORM, SPONSORED BY...    850000.00
# 5   MARIJUANA POLICY PROJECT OF CALIFORNIA, YES ON 64    739200.00
# 0          ADULT USE CAMPAIGN FOR PROPOSITION 64; THE     17089.00
# 6                         MOMS STRONG AGAINST PROP 64      6281.64

# %%
merged.groupby(["contributor_firstname", "contributor_lastname", "committee_position"]).amount.sum().reset_index().sort_values("amount", ascending=False)
# Out:
#     contributor_firstname            contributor_lastname committee_position  \
# 483                  SEAN  PARKER AND AFFILIATED ENTITIES            SUPPORT
# 482                  SEAN                          PARKER            SUPPORT
# 281                 JULIE                         SCHAUER             OPPOSE
# 108                DANIEL                           LEWIS            SUPPORT
# 194                 HENRY                   VAN AMERINGEN            SUPPORT
# 405              NICHOLAS                        PRITZKER            SUPPORT
# 421                 PETER                           THIEL            SUPPORT
# 456                 ROGER                         JENKINS            SUPPORT
# 23                 ANGELA                          HOWARD            SUPPORT
# 322              LAWRENCE                            HESS            SUPPORT
# 221                 JASON                            POST            SUPPORT
# ...

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 860 entries, 0 to 859
# Data columns (total 20 columns):
# ocd_prop_id                     860 non-null object
# calaccess_prop_id               860 non-null int64
# ccdc_prop_id                    860 non-null int64
# prop_name                       860 non-null object
# ccdc_committee_id               860 non-null int64
# calaccess_committee_id          860 non-null int64
# committee_name_x                860 non-null object
# committee_position              860 non-null object
# committee_name_y                860 non-null object
# calaccess_filing_id             860 non-null int64
# date_received                   860 non-null object
# contributor_lastname            860 non-null object
# contributor_firstname           750 non-null object
# contributor_city                860 non-null object
# contributor_state               860 non-null object
# contributor_zip                 860 non-null object
# ...

# %%
merged.groupby("contributor_state").amount.sum.reset_index()
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-44-c127a67deb3f> in <module>()
# ----> 1 merged.groupby("contributor_state").amount.sum.reset_index()
#
# AttributeError: 'function' object has no attribute 'reset_index'

# %%
merged.groupby("contributor_state")

# %%
merged.info
# Out:
# <bound method DataFrame.info of                                           ocd_prop_id  calaccess_prop_id  \
# 0    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 1    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 2    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 3    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 4    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 5    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 6    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 7    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 8    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 9    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 10   ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# ...

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 860 entries, 0 to 859
# Data columns (total 20 columns):
# ocd_prop_id                     860 non-null object
# calaccess_prop_id               860 non-null int64
# ccdc_prop_id                    860 non-null int64
# prop_name                       860 non-null object
# ccdc_committee_id               860 non-null int64
# calaccess_committee_id          860 non-null int64
# committee_name_x                860 non-null object
# committee_position              860 non-null object
# committee_name_y                860 non-null object
# calaccess_filing_id             860 non-null int64
# date_received                   860 non-null object
# contributor_lastname            860 non-null object
# contributor_firstname           750 non-null object
# contributor_city                860 non-null object
# contributor_state               860 non-null object
# contributor_zip                 860 non-null object
# ...

# %%
merged.sort_values("amount", "contributor_state"=False)
# Out:
#   File "<ipython-input-48-49ce7e800870>", line 1
#     merged.sort_values("amount", "contributor_state"=False)
# SyntaxError: keyword can't be an expression

# %%
merged.amount.sum()
# Out:
# 35177017.640000001

# %%
out_of_state = merged[merged.contributor_state =/= "CA"]
# Out:
#   File "<ipython-input-50-c2ed4e9be991>", line 1
#     out_of_state = merged[merged.contributor_state =/= "CA"]
#                                                    ^
# SyntaxError: invalid syntax

# %%
out_of_state = merged[merged.contributor_state is not "CA"]
# Out:
# KeyErrorTraceback (most recent call last)
# <ipython-input-51-16ccc8331261> in <module>()
# ----> 1 out_of_state = merged[merged.contributor_state is not "CA"]
#
# c:\code\first-python-notebook\lib\site-packages\pandas\core\frame.pyc in __getitem__(self, key)
#    1962             return self._getitem_multilevel(key)
#    1963         else:
# -> 1964             return self._getitem_column(key)
#    1965
#    1966     def _getitem_column(self, key):
#
# c:\code\first-python-notebook\lib\site-packages\pandas\core\frame.pyc in _getitem_column(self, key)
#    1969         # get column
#    1970         if self.columns.is_unique:
# -> 1971             return self._get_item_cache(key)
#    1972
#    1973         # duplicate columns & possible reduce dimensionality
#
# c:\code\first-python-notebook\lib\site-packages\pandas\core\generic.pyc in _get_item_cache(self, item)
#    1643         res = cache.get(item)
#    1644         if res is None:
# ...

# %%
out_of_state.info()
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-52-4a9bf60933db> in <module>()
# ----> 1 out_of_state.info()
#
# NameError: name 'out_of_state' is not defined

# %%
out_of_state = merged[merged.contributor_state != "CA"]

# %%
out_of_state.sum()
# Out:
# ocd_prop_id                     ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d17...
# calaccess_prop_id                                                       230771956
# ccdc_prop_id                                                                13861
# prop_name                       PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# ccdc_committee_id                                                           76873
# calaccess_committee_id                                                  227109697
# committee_name_x                YES ON 64, CALIFORNIANS TO CONTROL, REGULATE A...
# committee_position              SUPPORTSUPPORTSUPPORTSUPPORTSUPPORTSUPPORTSUPP...
# committee_name_y                YES ON 64, CALIFORNIANS TO CONTROL, REGULATE A...
# calaccess_filing_id                                                     346227046
# date_received                   2016-01-052016-02-022016-01-062016-06-302016-0...
# ...

# %%
out_of_state.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 167 entries, 4 to 859
# Data columns (total 20 columns):
# ocd_prop_id                     167 non-null object
# calaccess_prop_id               167 non-null int64
# ccdc_prop_id                    167 non-null int64
# prop_name                       167 non-null object
# ccdc_committee_id               167 non-null int64
# calaccess_committee_id          167 non-null int64
# committee_name_x                167 non-null object
# committee_position              167 non-null object
# committee_name_y                167 non-null object
# calaccess_filing_id             167 non-null int64
# date_received                   167 non-null object
# contributor_lastname            167 non-null object
# contributor_firstname           126 non-null object
# contributor_city                167 non-null object
# contributor_state               167 non-null object
# contributor_zip                 167 non-null object
# ...

# %%
out_of_state.amount.sum()
# Out:
# 17685824.640000001

# %%
merged.amount_sum()
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-58-efabd4d68c3e> in <module>()
# ----> 1 merged.amount_sum()
#
# c:\code\first-python-notebook\lib\site-packages\pandas\core\generic.pyc in __getattr__(self, name)
#    3079             if name in self._info_axis:
#    3080                 return self[name]
# -> 3081             return object.__getattribute__(self, name)
#    3082
#    3083     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'amount_sum'

# %%
merged.info
# Out:
# <bound method DataFrame.info of                                           ocd_prop_id  calaccess_prop_id  \
# 0    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 1    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 2    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 3    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 4    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 5    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 6    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 7    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 8    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 9    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 10   ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# ...

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 860 entries, 0 to 859
# Data columns (total 20 columns):
# ocd_prop_id                     860 non-null object
# calaccess_prop_id               860 non-null int64
# ccdc_prop_id                    860 non-null int64
# prop_name                       860 non-null object
# ccdc_committee_id               860 non-null int64
# calaccess_committee_id          860 non-null int64
# committee_name_x                860 non-null object
# committee_position              860 non-null object
# committee_name_y                860 non-null object
# calaccess_filing_id             860 non-null int64
# date_received                   860 non-null object
# contributor_lastname            860 non-null object
# contributor_firstname           750 non-null object
# contributor_city                860 non-null object
# contributor_state               860 non-null object
# contributor_zip                 860 non-null object
# ...

# %%
in_state = merged[merged.contributor_state = "CA"]
# Out:
#   File "<ipython-input-61-466b4eac38e0>", line 1
#     in_state = merged[merged.contributor_state = "CA"]
#                                                ^
# SyntaxError: invalid syntax

# %%
in_state = merged[merged.contributor_state == "CA"]

# %%
in_state.sum()
# Out:
# ocd_prop_id                     ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d17...
# calaccess_prop_id                                                       957634524
# ccdc_prop_id                                                                57519
# prop_name                       PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# ccdc_committee_id                                                          318190
# calaccess_committee_id                                                  945196070
# committee_name_x                YES ON 64, CALIFORNIANS TO CONTROL, REGULATE A...
# committee_position              SUPPORTSUPPORTSUPPORTSUPPORTSUPPORTSUPPORTSUPP...
# committee_name_y                YES ON 64, CALIFORNIANS TO CONTROL, REGULATE A...
# calaccess_filing_id                                                    1443199504
# date_received                   2016-02-042016-01-052016-01-292016-03-282016-0...
# ...

# %%
in_state.amount.sum()
# Out:
# 17491193.0

# %%
out_of_state.amount.sum()
# Out:
# 17685824.640000001

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 860 entries, 0 to 859
# Data columns (total 20 columns):
# ocd_prop_id                     860 non-null object
# calaccess_prop_id               860 non-null int64
# ccdc_prop_id                    860 non-null int64
# prop_name                       860 non-null object
# ccdc_committee_id               860 non-null int64
# calaccess_committee_id          860 non-null int64
# committee_name_x                860 non-null object
# committee_position              860 non-null object
# committee_name_y                860 non-null object
# calaccess_filing_id             860 non-null int64
# date_received                   860 non-null object
# contributor_lastname            860 non-null object
# contributor_firstname           750 non-null object
# contributor_city                860 non-null object
# contributor_state               860 non-null object
# contributor_zip                 860 non-null object
# ...

# %%
contribs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56379 entries, 0 to 56378
# Data columns (total 13 columns):
# calaccess_committee_id          56379 non-null int64
# committee_name                  56379 non-null object
# calaccess_filing_id             56379 non-null int64
# date_received                   56379 non-null object
# contributor_lastname            56375 non-null object
# contributor_firstname           53411 non-null object
# contributor_city                56369 non-null object
# contributor_state               56363 non-null object
# contributor_zip                 56366 non-null object
# contributor_employer            48572 non-null object
# contributor_occupation          53273 non-null object
# contributor_is_self_employed    56379 non-null bool
# amount                          56379 non-null float64
# dtypes: bool(1), float64(1), int64(2), object(9)
# memory usage: 5.2+ MB

# %%
committees = contribs[contribs."calaccess_committee_id"]
# Out:
#   File "<ipython-input-68-523fc39883e6>", line 1
#     committees = contribs[contribs."calaccess_committee_id"]
#                                                           ^
# SyntaxError: invalid syntax

# %%
committees = contribs["calaccess_committee_id"]

# %%
committess.info()
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-70-31c2ea18170e> in <module>()
# ----> 1 committess.info()
#
# NameError: name 'committess' is not defined

# %%
committees.info()
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-71-f66b6e2e7c41> in <module>()
# ----> 1 committees.info()
#
# c:\code\first-python-notebook\lib\site-packages\pandas\core\generic.pyc in __getattr__(self, name)
#    3079             if name in self._info_axis:
#    3080                 return self[name]
# -> 3081             return object.__getattribute__(self, name)
#    3082
#    3083     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'info'

# %%
print committees
# Out:
# 0        1386560
# 1        1386560
# 2        1386560
# 3        1386560
# 4        1386560
# 5        1386560
# 6        1386560
# 7        1386560
# 8        1386560
# 9        1386560
# 10       1386560
# 11       1386560
# 12       1386560
# 13       1386560
# 14       1386560
# 15       1386560
# 16       1386560
# 17       1386560
# 18       1386560
# 19       1386560
# 20       1386560
# 21       1386560
# 22       1386560
# 23       1386560
# 24       1386560
# 25       1386560
# 26       1372902
# 27       1372902
# 28       1372902
# 29       1372902
#           ...
# 56349    1374469
# 56350    1374469
# 56351    1374469
# 56352    1374469
# 56353    1374469
# 56354    1374469
# 56355    1374469
# 56356    1374469
# 56357    1374469
# 56358    1374469
# 56359    1374469
# 56360    1374469
# 56361    1374469
# 56362    1374469
# 56363    1374469
# 56364    1374469
# 56365    1374469
# 56366    1374469
# 56367    1362973
# 56368    1362973
# 56369    1362973
# ...

# %%
contribs = pd.read_csv("http://www.firstpythonnotebook.org/_static/contributions.csv")

# %%
contribs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56379 entries, 0 to 56378
# Data columns (total 13 columns):
# calaccess_committee_id          56379 non-null int64
# committee_name                  56379 non-null object
# calaccess_filing_id             56379 non-null int64
# date_received                   56379 non-null object
# contributor_lastname            56375 non-null object
# contributor_firstname           53411 non-null object
# contributor_city                56369 non-null object
# contributor_state               56363 non-null object
# contributor_zip                 56366 non-null object
# contributor_employer            48572 non-null object
# contributor_occupation          53273 non-null object
# contributor_is_self_employed    56379 non-null bool
# amount                          56379 non-null float64
# dtypes: bool(1), float64(1), int64(2), object(9)
# memory usage: 5.2+ MB

# %%
print contribs
# Out:
#        calaccess_committee_id  \
# 0                     1386560
# 1                     1386560
# 2                     1386560
# 3                     1386560
# 4                     1386560
# 5                     1386560
# 6                     1386560
# 7                     1386560
# 8                     1386560
# 9                     1386560
# 10                    1386560
# 11                    1386560
# 12                    1386560
# 13                    1386560
# 14                    1386560
# 15                    1386560
# 16                    1386560
# 17                    1386560
# 18                    1386560
# 19                    1386560
# 20                    1386560
# 21                    1386560
# 22                    1386560
# 23                    1386560
# 24                    1386560
# 25                    1386560
# 26                    1372902
# 27                    1372902
# 28                    1372902
# 29                    1372902
# ...

# %%
pd.read_csv("C:\Code\gov_contribs.csv")
# Out:
# c:\code\first-python-notebook\lib\site-packages\IPython\core\interactiveshell.py:2718: DtypeWarning: Columns (26,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#         FILING_ID  AMEND_ID  LINE_ITEM REC_TYPE FORM_TYPE TRAN_ID ENTITY_CD  \
# 0          716897         0          3     CVR2      F465     FO3       OFF
# 1          716905         0          1     CVR2      F465     FO1       OFF
# 2          716905         0          2     CVR2      F465     FO2       OFF
# 3          716905         0          3     CVR2      F465     FO3       OFF
# 4          716906         0          1     CVR2      F465     FO1       OFF
# 5          716906         0          2     CVR2      F465     FO2       OFF
# 6          716906         0          3     CVR2      F465     FO3       OFF
# 7          716908         0          1     CVR2      F465     FO1       OFF
# ...

# %%
pd.read_csv("C:\Code\rcpt_cd.csv")
# Out:
# IOErrorTraceback (most recent call last)
# <ipython-input-77-443370bef819> in <module>()
# ----> 1 pd.read_csv("C:\Code\rcpt_cd.csv")
#
# c:\code\first-python-notebook\lib\site-packages\pandas\io\parsers.pyc in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     653                     skip_blank_lines=skip_blank_lines)
#     654
# ...

# %%
pd.read_csv("C:\Code\contribs1.csv")

# %%
contribs1 = pd.read_csv("C:\Code\contribs1.csv")

# %%
print contribs1

# %%
contribs1.info()

# %%
print contribs1
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-1-ffafe02e1de6> in <module>()
# ----> 1 print contribs1
#
# NameError: name 'contribs1' is not defined
